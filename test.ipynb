# %%
# !python setup.py install
# Out:
# /home/jmcfaul/pyrkenv/lib64/python3.8/site-packages/setuptools/dist.py:480: UserWarning: The version specified ('0.2.devfaa3b6f') is an invalid version, this may not work as expected with newer versions of setuptools, pip, and PyPI. Please see PEP 440 for more details.
#   warnings.warn(
# running install
# running bdist_egg
# running egg_info
# writing pyrk.egg-info/PKG-INFO
# writing dependency_links to pyrk.egg-info/dependency_links.txt
# writing requirements to pyrk.egg-info/requires.txt
# writing top-level names to pyrk.egg-info/top_level.txt
# reading manifest file 'pyrk.egg-info/SOURCES.txt'
# writing manifest file 'pyrk.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/pyrk
# copying build/lib/pyrk/__init__.py -> build/bdist.linux-x86_64/egg/pyrk
# copying build/lib/pyrk/convective_model.py -> build/bdist.linux-x86_64/egg/pyrk
# copying build/lib/pyrk/driver.py -> build/bdist.linux-x86_64/egg/pyrk
# copying build/lib/pyrk/neutronics.py -> build/bdist.linux-x86_64/egg/pyrk
# copying build/lib/pyrk/reactivity_insertion.py -> build/bdist.linux-x86_64/egg/pyrk
# copying build/lib/pyrk/th_system.py -> build/bdist.linux-x86_64/egg/pyrk
# copying build/lib/pyrk/timer.py -> build/bdist.linux-x86_64/egg/pyrk
# copying build/lib/pyrk/ver.py -> build/bdist.linux-x86_64/egg/pyrk
# creating build/bdist.linux-x86_64/egg/pyrk/data
# copying build/lib/pyrk/data/__init__.py -> build/bdist.linux-x86_64/egg/pyrk/data
# copying build/lib/pyrk/data/decay_heat.py -> build/bdist.linux-x86_64/egg/pyrk/data
# copying build/lib/pyrk/data/precursors.py -> build/bdist.linux-x86_64/egg/pyrk/data
# creating build/bdist.linux-x86_64/egg/pyrk/data/.ipynb_checkpoints
# copying build/lib/pyrk/data/.ipynb_checkpoints/precursors-checkpoint.py -> build/bdist.linux-x86_64/egg/pyrk/data/.ipynb_checkpoints
# creating build/bdist.linux-x86_64/egg/pyrk/db
# copying build/lib/pyrk/db/__init__.py -> build/bdist.linux-x86_64/egg/pyrk/db
# copying build/lib/pyrk/db/database.py -> build/bdist.linux-x86_64/egg/pyrk/db
# copying build/lib/pyrk/db/descriptions.py -> build/bdist.linux-x86_64/egg/pyrk/db
# creating build/bdist.linux-x86_64/egg/pyrk/inp
# copying build/lib/pyrk/inp/__init__.py -> build/bdist.linux-x86_64/egg/pyrk/inp
# copying build/lib/pyrk/inp/sim_info.py -> build/bdist.linux-x86_64/egg/pyrk/inp
# copying build/lib/pyrk/inp/validation.py -> build/bdist.linux-x86_64/egg/pyrk/inp
# creating build/bdist.linux-x86_64/egg/pyrk/materials
# copying build/lib/pyrk/materials/__init__.py -> build/bdist.linux-x86_64/egg/pyrk/materials
# copying build/lib/pyrk/materials/fhrfuel.py -> build/bdist.linux-x86_64/egg/pyrk/materials
# copying build/lib/pyrk/materials/flibe.py -> build/bdist.linux-x86_64/egg/pyrk/materials
# copying build/lib/pyrk/materials/graphite.py -> build/bdist.linux-x86_64/egg/pyrk/materials
# copying build/lib/pyrk/materials/kernel.py -> build/bdist.linux-x86_64/egg/pyrk/materials
# copying build/lib/pyrk/materials/liquid_material.py -> build/bdist.linux-x86_64/egg/pyrk/materials
# copying build/lib/pyrk/materials/material.py -> build/bdist.linux-x86_64/egg/pyrk/materials
# copying build/lib/pyrk/materials/sfrmetal.py -> build/bdist.linux-x86_64/egg/pyrk/materials
# copying build/lib/pyrk/materials/sodium.py -> build/bdist.linux-x86_64/egg/pyrk/materials
# copying build/lib/pyrk/materials/ss316.py -> build/bdist.linux-x86_64/egg/pyrk/materials
# copying build/lib/pyrk/materials/trisos.py -> build/bdist.linux-x86_64/egg/pyrk/materials
# creating build/bdist.linux-x86_64/egg/pyrk/materials/.ipynb_checkpoints
# copying build/lib/pyrk/materials/.ipynb_checkpoints/kernel-checkpoint.py -> build/bdist.linux-x86_64/egg/pyrk/materials/.ipynb_checkpoints
# copying build/lib/pyrk/materials/.ipynb_checkpoints/material-checkpoint.py -> build/bdist.linux-x86_64/egg/pyrk/materials/.ipynb_checkpoints
# copying build/lib/pyrk/materials/.ipynb_checkpoints/liquid_material-checkpoint.py -> build/bdist.linux-x86_64/egg/pyrk/materials/.ipynb_checkpoints
# copying build/lib/pyrk/materials/.ipynb_checkpoints/__init__-checkpoint.py -> build/bdist.linux-x86_64/egg/pyrk/materials/.ipynb_checkpoints
# copying build/lib/pyrk/materials/.ipynb_checkpoints/fhrfuel-checkpoint.py -> build/bdist.linux-x86_64/egg/pyrk/materials/.ipynb_checkpoints
# copying build/lib/pyrk/materials/gas_material.py -> build/bdist.linux-x86_64/egg/pyrk/materials
# copying build/lib/pyrk/materials/helium.py -> build/bdist.linux-x86_64/egg/pyrk/materials
# creating build/bdist.linux-x86_64/egg/pyrk/utilities
# copying build/lib/pyrk/utilities/__init__.py -> build/bdist.linux-x86_64/egg/pyrk/utilities
# copying build/lib/pyrk/utilities/exceptions.py -> build/bdist.linux-x86_64/egg/pyrk/utilities
# copying build/lib/pyrk/utilities/logger.py -> build/bdist.linux-x86_64/egg/pyrk/utilities
# copying build/lib/pyrk/utilities/plotter.py -> build/bdist.linux-x86_64/egg/pyrk/utilities
# copying build/lib/pyrk/utilities/ur.py -> build/bdist.linux-x86_64/egg/pyrk/utilities
# copying build/lib/pyrk/driver_test.py -> build/bdist.linux-x86_64/egg/pyrk
# creating build/bdist.linux-x86_64/egg/pyrk/.ipynb_checkpoints
# copying build/lib/pyrk/.ipynb_checkpoints/reactivity_insertion-checkpoint.py -> build/bdist.linux-x86_64/egg/pyrk/.ipynb_checkpoints
# copying build/lib/pyrk/.ipynb_checkpoints/neutronics-checkpoint.py -> build/bdist.linux-x86_64/egg/pyrk/.ipynb_checkpoints
# copying build/lib/pyrk/.ipynb_checkpoints/__init__-checkpoint.py -> build/bdist.linux-x86_64/egg/pyrk/.ipynb_checkpoints
# copying build/lib/pyrk/.ipynb_checkpoints/ver-checkpoint.py -> build/bdist.linux-x86_64/egg/pyrk/.ipynb_checkpoints
# copying build/lib/pyrk/.ipynb_checkpoints/density_model-checkpoint.py -> build/bdist.linux-x86_64/egg/pyrk/.ipynb_checkpoints
# copying build/lib/pyrk/.ipynb_checkpoints/driver_test-checkpoint.py -> build/bdist.linux-x86_64/egg/pyrk/.ipynb_checkpoints
# copying build/lib/pyrk/th_component-Fix.py -> build/bdist.linux-x86_64/egg/pyrk
# copying build/lib/pyrk/th_component.py -> build/bdist.linux-x86_64/egg/pyrk
# copying build/lib/pyrk/conductive-model1.py -> build/bdist.linux-x86_64/egg/pyrk
# copying build/lib/pyrk/conductive_model.py -> build/bdist.linux-x86_64/egg/pyrk
# copying build/lib/pyrk/th_componentFix.py -> build/bdist.linux-x86_64/egg/pyrk
# copying build/lib/pyrk/density_model.py -> build/bdist.linux-x86_64/egg/pyrk
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/convective_model.py to convective_model.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/driver.py to driver.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/neutronics.py to neutronics.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/reactivity_insertion.py to reactivity_insertion.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/th_system.py to th_system.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/timer.py to timer.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/ver.py to ver.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/data/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/data/decay_heat.py to decay_heat.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/data/precursors.py to precursors.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/data/.ipynb_checkpoints/precursors-checkpoint.py to precursors-checkpoint.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/db/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/db/database.py to database.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/db/descriptions.py to descriptions.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/inp/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/inp/sim_info.py to sim_info.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/inp/validation.py to validation.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/materials/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/materials/fhrfuel.py to fhrfuel.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/materials/flibe.py to flibe.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/materials/graphite.py to graphite.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/materials/kernel.py to kernel.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/materials/liquid_material.py to liquid_material.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/materials/material.py to material.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/materials/sfrmetal.py to sfrmetal.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/materials/sodium.py to sodium.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/materials/ss316.py to ss316.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/materials/trisos.py to trisos.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/materials/.ipynb_checkpoints/kernel-checkpoint.py to kernel-checkpoint.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/materials/.ipynb_checkpoints/material-checkpoint.py to material-checkpoint.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/materials/.ipynb_checkpoints/liquid_material-checkpoint.py to liquid_material-checkpoint.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/materials/.ipynb_checkpoints/__init__-checkpoint.py to __init__-checkpoint.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/materials/.ipynb_checkpoints/fhrfuel-checkpoint.py to fhrfuel-checkpoint.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/materials/gas_material.py to gas_material.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/materials/helium.py to helium.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/utilities/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/utilities/exceptions.py to exceptions.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/utilities/logger.py to logger.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/utilities/plotter.py to plotter.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/utilities/ur.py to ur.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/driver_test.py to driver_test.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/.ipynb_checkpoints/reactivity_insertion-checkpoint.py to reactivity_insertion-checkpoint.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/.ipynb_checkpoints/neutronics-checkpoint.py to neutronics-checkpoint.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/.ipynb_checkpoints/__init__-checkpoint.py to __init__-checkpoint.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/.ipynb_checkpoints/ver-checkpoint.py to ver-checkpoint.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/.ipynb_checkpoints/density_model-checkpoint.py to density_model-checkpoint.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/.ipynb_checkpoints/driver_test-checkpoint.py to driver_test-checkpoint.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/th_component-Fix.py to th_component-Fix.cpython-38.pyc
# Sorry: IndentationError: expected an indented block (th_component-Fix.py, line 250)
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/th_component.py to th_component.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/conductive-model1.py to conductive-model1.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/conductive_model.py to conductive_model.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/th_componentFix.py to th_componentFix.cpython-38.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrk/density_model.py to density_model.cpython-38.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying pyrk.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pyrk.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pyrk.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pyrk.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pyrk.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# pyrk.__pycache__.driver.cpython-38: module references __file__
# creating 'dist/pyrk-0.2.devfaa3b6f-py3.8.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing pyrk-0.2.devfaa3b6f-py3.8.egg
# removing '/home/jmcfaul/pyrkenv/lib/python3.8/site-packages/pyrk-0.2.devfaa3b6f-py3.8.egg' (and everything under it)
# creating /home/jmcfaul/pyrkenv/lib/python3.8/site-packages/pyrk-0.2.devfaa3b6f-py3.8.egg
# Extracting pyrk-0.2.devfaa3b6f-py3.8.egg to /home/jmcfaul/pyrkenv/lib/python3.8/site-packages
# Sorry: IndentationError: expected an indented block (th_component-Fix.py, line 250)
# pyrk 0.2.devfaa3b6f is already the active version in easy-install.pth
#
# Installed /home/jmcfaul/pyrkenv/lib/python3.8/site-packages/pyrk-0.2.devfaa3b6f-py3.8.egg
# Processing dependencies for pyrk===0.2.devfaa3b6f
# Finished processing dependencies for pyrk===0.2.devfaa3b6f

# %%
# !python pyrk/driver.py --infile=examples/default/kairosModHGStartParams2.py --plotdir=outputs/kairosModHGStartParams2
# Out:
# 2025-04-07 19:22:26,609 - pyrklog - CRITICAL
#
# Welcome to PyRK.
# (c) Kathryn D. Huff
# Your simulation is starting.
# Perhaps it's time for a coffee.
#
#
#
#                  ,,,,yggyQQQQQQQQQQQQQQQQQyyyy,,,,
#         ,,gQQQQQQQQQQQQ#WWWEEEEERRRREEEEWWW#QQQQQQQQQQQQQy,,
#    ,gQQQQQQWR"D^^.-~~'~~WW~-..aQ     ,},,....... ,.``?RW@QQQQQQ,
#  ,QQQWR^.           ,`Bm-gj^@L  .gyy, ``Q~-,,,a~^^         ^"WQQQQ
#  @QQQy      ,-~^`          jQ,,DMmnmGQ`|Q        `"~.        ,#QQQ,
#  @QQQQQQQQy,, `````         Q          #`    ````^""^^,,y#QQQQQQQQQQQQQg
#  @QQQQQQQQQQQQQQQQQQQyyyy,,QQ@Q,,,,,,#Q,,,,ygg#QQQQQQQQQQQQQQQQQQQQQQQQQQQQ
#  ]QQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQ"RRQQQQQQQQ
#   QQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQ    `@QQQQQQ
#   QQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQM      "QQQQQQ
#   @QQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQ        ]QQQQQ
#   'QQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQM        ]QQQQQ
#    @QQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQ         QQQQQ
#     QQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQM       ,QQQQQ^
#     ]QQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQ     ,gQQQQQR
#      @QQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQyQQQQQQQQQM^
#       @QQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQ#WR^`
#        @QQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQ^
#         @QQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQ~
#          "QQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQE
#            YQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQ#^
#             'YQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQ#T
#                ?@QQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQQR
#                  `?RQQQQQQQQQQQQQQQQQQQQQQQQQQQ#R^
#                       7RRQQQQQQQQQQQQQQQQQWE"`.
#
# /home/jmcfaul/pyrkenv/lib64/python3.8/site-packages/scipy/integrate/_ode.py:1174: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   x, y, iwork, istate = self.runner(*((f, t0, y0, t1) +
# outputs/kairosModHGStartParams2
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# 2025-04-07 19:32:06,599 - pyrklog - CRITICAL
#
# Simulation succeeded.

# %%
import numpy as np
from scipy.integrate import ode
import importlib
import argparse
from pyrk.db import database
from pyrk.utilities import logger
from pyrk.utilities import plotter
from pyrk.utilities.logger import pyrklog
from pyrk.inp import sim_info
from pyrk.utilities.ur import units
import os

# %%
t = np.random.randint(2,10)
t = t * units.seconds 
print(t)
# Out:
# 4 second

# %%
def update_n(t, y_n, si):
    """This function updates the neutronics block.

    :param t: the time [s] at which the update is occuring.
    :type t: float.
    :param y_n: The array that solves the neutronics block at time t
    :type y_n: np.ndarray.
    """
    t_idx = si.timer.t_idx(t * units.seconds)
    n_n = len(y_n)
    si.y[t_idx][:n_n] = y_n

# %%
from pyrk.utilities.ur import units

# %%
# !pip install numpy
# Out:
# Collecting numpy
#   Downloading https://files.pythonhosted.org/packages/98/5d/5738903efe0ecb73e51eb44feafba32bdba2081263d40c5043568ff60faf/numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3MB)
#      |████████████████████████████████| 17.3MB 13.6MB/s eta 0:00:01
# Installing collected packages: numpy
# Successfully installed numpy-1.24.4
# WARNING: You are using pip version 19.3.1; however, version 24.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install pint
# Out:
# Collecting pint
#   Downloading https://files.pythonhosted.org/packages/49/bc/7ef2a654754cc3179af8df837485931f0874d96e111005a6246c1ed695f2/Pint-0.21.1-py3-none-any.whl (290kB)
#      |████████████████████████████████| 296kB 26.4MB/s eta 0:00:01
# Installing collected packages: pint
# Successfully installed pint-0.21.1
# WARNING: You are using pip version 19.3.1; however, version 24.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install scipy
# Out:
# Collecting scipy
#   Downloading https://files.pythonhosted.org/packages/69/f0/fb07a9548e48b687b8bf2fa81d71aba9cfc548d365046ca1c791e24db99d/scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5MB)
#      |████████████████████████████████| 34.5MB 30.4MB/s eta 0:00:01
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /home/jmcfaul/pyrkenv/lib/python3.8/site-packages (from scipy) (1.24.4)
# Installing collected packages: scipy
# Successfully installed scipy-1.10.1
# WARNING: You are using pip version 19.3.1; however, version 24.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
t = 1
t = t * units.seconds
print(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 t = 1
# ----> 2 t = t * units.seconds
#       3 print(t)
#
# NameError: name 'units' is not defined

# %%
# !pip install tables
# Out:
# Collecting tables
#   Downloading https://files.pythonhosted.org/packages/05/49/e392c92132b950c3a8bdbb66c687a82e808edd89024e73358084bf96e044/tables-3.8.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5MB)
#      |████████████████████████████████| 6.5MB 29.5MB/s eta 0:00:01
# Collecting py-cpuinfo
#   Downloading https://files.pythonhosted.org/packages/e0/a9/023730ba63db1e494a271cb018dcd361bd2c917ba7004c3e49d5daf795a2/py_cpuinfo-9.0.0-py3-none-any.whl
# Collecting cython>=0.29.21
#   Downloading https://files.pythonhosted.org/packages/b2/52/eda119f98071ccde04a9a1c9c9a18fd6def025651c9d0cd01ad51d0dba36/Cython-3.0.11-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6MB)
#      |████████████████████████████████| 3.6MB 82.3MB/s eta 0:00:01
# Collecting numexpr>=2.6.2
#   Downloading https://files.pythonhosted.org/packages/0d/47/a2ede0e136a8ddc288b447c260aa035f3e75251f808aa61f6454b16dfd04/numexpr-2.8.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (384kB)
#      |████████████████████████████████| 389kB 64.8MB/s eta 0:00:01
# Collecting blosc2~=2.0.0
#   Downloading https://files.pythonhosted.org/packages/a6/dd/7e214303c2acb0807fd1ad86d78112456c0fc9397f565ab86ebd147f2a9b/blosc2-2.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.9MB)
#      |████████████████████████████████| 3.9MB 71.8MB/s eta 0:00:01
# Requirement already satisfied: packaging in /home/jmcfaul/pyrkenv/lib/python3.8/site-packages (from tables) (24.2)
# Requirement already satisfied: numpy>=1.19.0 in /home/jmcfaul/pyrkenv/lib/python3.8/site-packages (from tables) (1.24.4)
# Collecting msgpack
#   Downloading https://files.pythonhosted.org/packages/55/f6/d4859a158a915be52eecd52dee9761ab3a5d84c834a1d13ffc198e068a48/msgpack-1.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (381kB)
#      |████████████████████████████████| 389kB 87.4MB/s eta 0:00:01
# Installing collected packages: py-cpuinfo, cython, numexpr, msgpack, blosc2, tables
# Successfully installed blosc2-2.0.0 cython-3.0.11 msgpack-1.1.0 numexpr-2.8.6 py-cpuinfo-9.0.0 tables-3.8.0
# WARNING: You are using pip version 19.3.1; however, version 24.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading https://files.pythonhosted.org/packages/30/33/cc27211d2ffeee4fd7402dca137b6e8a83f6dcae3d4be8d0ad5068555561/matplotlib-3.7.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2MB)
#      |████████████████████████████████| 9.2MB 26.9MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /home/jmcfaul/pyrkenv/lib/python3.8/site-packages (from matplotlib) (24.2)
# Collecting pyparsing>=2.3.1
#   Downloading https://files.pythonhosted.org/packages/e5/0c/0e3c05b1c87bb6a1c76d281b0f35e78d2d80ac91b5f8f524cebf77f51049/pyparsing-3.1.4-py3-none-any.whl (104kB)
#      |████████████████████████████████| 112kB 98.2MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading https://files.pythonhosted.org/packages/b5/10/8057a6c234637e290e7df88fac048108a2f8c8fc36e0da2216945b67f47b/fonttools-4.55.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7MB)
#      |████████████████████████████████| 4.7MB 76.5MB/s eta 0:00:01
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /home/jmcfaul/pyrkenv/lib/python3.8/site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in /home/jmcfaul/pyrkenv/lib/python3.8/site-packages (from matplotlib) (1.24.4)
# Collecting kiwisolver>=1.0.1
#   Downloading https://files.pythonhosted.org/packages/76/36/ae40d7a3171e06f55ac77fe5536079e7be1d8be2a8210e08975c7f9b4d54/kiwisolver-1.4.7-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 89.7MB/s eta 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading https://files.pythonhosted.org/packages/8e/71/7f20855592cc929bc206810432b991ec4c702dc26b0567b132e52c85536f/contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301kB)
#      |████████████████████████████████| 307kB 91.4MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2.7 in /home/jmcfaul/pyrkenv/lib/python3.8/site-packages (from matplotlib) (2.9.0.post0)
# Collecting pillow>=6.2.0
#   Downloading https://files.pythonhosted.org/packages/84/4c/69bbed9e436ac22f9ed193a2b64f64d68fcfbc9f4106249dc7ed4889907b/pillow-10.4.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4MB)
#      |████████████████████████████████| 4.5MB 75.6MB/s eta 0:00:01
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/jmcfaul/pyrkenv/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib) (3.20.2)
# Requirement already satisfied: six>=1.5 in /home/jmcfaul/pyrkenv/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: pyparsing, fonttools, kiwisolver, contourpy, cycler, pillow, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.55.3 kiwisolver-1.4.7 matplotlib-3.7.5 pillow-10.4.0 pyparsing-3.1.4
# WARNING: You are using pip version 19.3.1; however, version 24.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
#! /usr/bin/env python

# Licensed under a 3-clause BSD style license - see LICENSE.rst
"""
This is an example driver for the simulation. It should soon be refactored to
result in an input file, an input parser, a solver interface, and output
scripts.
"""

import numpy as np
from scipy.integrate import ode
import importlib
import argparse
from pyrk.db import database
from pyrk.utilities import logger
from pyrk.utilities import plotter
from pyrk.utilities.logger import pyrklog
from pyrk.inp import sim_info
from pyrk.utilities.ur import units
import os


def update_n(t, y_n, si):
    """This function updates the neutronics block.

    :param t: the time [s] at which the update is occuring.
    :type t: float.
    :param y_n: The array that solves the neutronics block at time t
    :type y_n: np.ndarray.
    """
    t_idx = si.timer.t_idx(t * units.seconds)
    n_n = len(y_n)
    si.y[t_idx][:n_n] = y_n


def update_th(t, y_n, y_th, si):
    """This function updates the thermal hydraulics block.

    :param t: the time [s] at which the update is occuring.
    :type t: float.

    :param y_th: The array that solves thermal hydraulics block at time t
    :type y_th: np.ndarray.
    """
    t_idx = si.timer.t_idx(t * units.seconds)
    for idx, comp in enumerate(si.components):
        comp.update_temp(t_idx, y_th[idx] * units.kelvin)
    n_n = len(y_n)
    si.y[t_idx][n_n:] = y_th


def f_n(t, y, si):
    """Returns the neutronics block solution at time t

    :param t: the time [s] at which the update is occuring.
    :type t: float.
    :param y: solution vector
    :type y: np.ndarray
    """
    n_n = 1 + si.n_pg + si.n_dg
    if len(y) < n_n:
        msg = 'equation numbers %d ' % len(y)
        msg += 'should be at least the number of neutronics equations %d' % n_n
        raise ValueError(msg)
    end_pg = 1 + si.n_pg
    f = np.zeros(shape=(n_n,), dtype=float)
    i = 0
    f[i] = si.ne.dpdt(si.timer.ts,
                      si.components,
                      y[0],
                      y[1:end_pg])
    for j in range(0, si.n_pg):
        i += 1
        f[i] = si.ne.dzetadt(t, y[0], y[i], j)
    assert i == end_pg - 1
    for k in range(0, si.n_dg):
        i += 1
        f[i] = si.ne.dwdt(y[0], y[i], k)
    return f


def f_th(t, y_th, si):
    """Returns the thermal hydraulics solution at time t

    :param t: the time [s] at which the update is occuring.
    :type t: float.
    :param y: the solution vector
    :type y: np.ndarray
    :param si: the simulation info object
    :type si: SimInfo
    """
    t_idx = si.timer.t_idx(t * units.seconds)
    f = units.Quantity(np.zeros(shape=(si.n_components(),), dtype=float),
                       'kelvin / second')
    power = si.y[t_idx][0]
    o_i = 1 + si.n_pg
    o_f = 1 + si.n_pg + si.n_dg
    omegas = si.y[t_idx][o_i:o_f]
    for idx, comp in enumerate(si.components):
        f[idx] = si.th.dtempdt(component=comp,
                               power=power,
                               omegas=omegas,
                               t_idx=t_idx)
    return f


def y0(si):
    """The initial conditions for y

    :param si: the simulation info object
    :type si: SimInfo
    """
    i = 0
    end_pg = 1 + si.n_pg
    end_dg = 1 + si.n_pg + si.n_dg
    f = np.zeros(shape=(si.n_entries(),), dtype=float)
    f[i] = 1.0  # power is normalized is 1
    for j in range(0, si.n_pg):
        i += 1
        f[i] = f[0] * \
            si.ne._pd.betas()[j] / (si.ne._pd.lambdas()[j] * si.ne._pd._Lambda)
    assert i == end_pg - 1
    for k in range(0, si.n_dg):
        i += 1
        f[i] = 0
    assert i == end_dg - 1
    for idx, comp in enumerate(si.components):
        f[i + idx + 1] = comp.T0.magnitude
    assert len(f) == si.n_entries()
    si.y[0] = f
    return f


def y0_n(si):
    """Initial conditions for y_n, the neutronics sub-block of y

    :param si: the simulation info object
    :type si: SimInfo
    """
    idx = si.n_pg + si.n_dg + 1
    y = y0(si)[:idx]
    return y


def y0_th(si):
    """Initial conditions for y_th, the thermal hydraulics sub-block of y

    :param si: the simulation info object
    :type si: SimInfo
    """
    thidx = si.n_pg + si.n_dg + 1
    y = y0(si)[thidx:]
    return y


def solve(si, y, infile):
    """Conducts the solution step, based on the dopri5 integrator in scipy

    :param si: the simulation info object
    :type si: SimInfo
    :param y: the solution vector
    :type y: np.ndarray
    :param infile: the imported infile module
    :type infile: imported module
    """
    n = ode(f_n).set_integrator('dopri5')
    n.set_initial_value(y0_n(si), si.timer.
                        t0.magnitude)
    n.set_f_params(si)
    th = ode(f_th).set_integrator('dopri5', nsteps=infile.nsteps)
    th.set_initial_value(y0_th(si), si.timer.t0.magnitude)
    th.set_f_params(si)
    while (n.successful() and
           n.t < si.timer.tf.magnitude and
           th.t < si.timer.tf.magnitude):
        si.timer.advance_one_timestep()
        si.db.record_all()
        n.integrate(si.timer.current_time().magnitude)
        update_n(n.t, n.y, si)
        th.integrate(si.timer.current_time().magnitude)
        update_th(th.t, n.y, th.y, si)
    return si.y


def log_results(si):
    pyrklog.info("\nReactivity : \n" + str(si.ne._rho))
    pyrklog.info("\nFinal Result : \n" + np.array_str(si.y))
    for comp in si.components:
        pyrklog.info("\n" + comp.name + ":\n" + np.array_str(comp.T.magnitude))
    pyrklog.info("\nPrecursor lambdas: \n" + str(si.ne._pd.lambdas()))
    pyrklog.info("\nDelayed neutron frac: \n" + str(si.ne._pd.beta()))
    pyrklog.info("\nPrecursor betas: \n" + str(si.ne._pd.betas()))
    pyrklog.info("\nDecay kappas: \n" + str(si.ne._dd.kappas()))
    pyrklog.info("\nDecay lambdas: \n" + str(si.ne._dd.lambdas()))


def print_logo(curr_dir):
    filename = os.path.join(curr_dir, 'logo.txt')
    with open(filename, 'r') as logo:
        pyrklog.critical("\nWelcome to PyRK.\n" +
                         "(c) Kathryn D. Huff\n" +
                         "Your simulation is starting.\n" +
                         "Perhaps it's time for a coffee.\n" +
                         logo.read())


def name_from_path(infile_path):
    """Returns just the base of the filename from the path

    :param infile_path: path to infile. (absolute, relative, or missing
      extension okay)"
    :type infile_path: string
    :return: returns the base name without the extension or path
    :rtype: string
    """
    import os.path
    import sys
    file_dir = os.path.dirname(infile_path)
    sys.path.append(file_dir)
    file_name = os.path.basename(infile_path)
    file_name_base = os.path.splitext(file_name)[0]
    return file_name_base


def load_infile(infile_path):
    """Loads the input file as a python package import based on the path

    :param infile_path: path to the infile
    :type infile_path: string
    """
    file_name = name_from_path(infile_path)
    infile = importlib.import_module(file_name)
    return infile


def main(args, curr_dir):
    np.set_printoptions(precision=5, threshold=np.inf)
    logger.set_up_pyrklog(args.logfile)
    infile = load_infile(args.infile)
    out_db = database.Database(filepath=args.outfile)
    if not hasattr(infile, 'n_ref'):
        n_ref = 0
    else:
        n_ref = infile.n_ref
    si = sim_info.SimInfo(timer=infile.ti,
                          components=infile.components,
                          iso=infile.fission_iso,
                          e=infile.spectrum,
                          n_precursors=infile.n_pg,
                          n_decay=infile.n_dg,
                          n_fic=n_ref,
                          kappa=infile.kappa,
                          feedback=infile.feedback,
                          rho_ext=infile.rho_ext,
                          plotdir=args.plotdir,
                          infile=args.infile,
                          db=out_db)
    # TODO: think about weather to add n_ref to all input files, or put n_ref
    # in database files
    print_logo(curr_dir)
    sol = solve(si=si, y=si.y, infile=infile)
    log_results(si)
    out_db.close_db()
    print(si.plotdir)
    plotter.plot(sol, si)
    pyrklog.critical("\nSimulation succeeded.\n")


"""Run it as a script"""
if __name__ == "__main__":
    curr_dir = os.path.dirname('pyrk/examples/sfr/input.py')
    ap = argparse.ArgumentParser(description='PyRK parameters')
    ap.add_argument('--infile', help='the name of the input file',
                    default='input')
    ap.add_argument('--logfile', help='the name of the log file',
                    default='pyrk.log')
    ap.add_argument(
        '--plotdir',
        help='the name of the directory of output plots',
        default='images')
    ap.add_argument('--outfile', help='the name of the output database',
                    default='pyrk.h5')
    args = ap.parse_args()
    main(args, curr_dir)
# Out:
# usage: ipykernel_launcher.py [-h] [--infile INFILE] [--logfile LOGFILE]
#                              [--plotdir PLOTDIR] [--outfile OUTFILE]
# ipykernel_launcher.py: error: unrecognized arguments: -f /home/jmcfaul/.local/share/jupyter/runtime/kernel-3a3047a0-7c40-4281-ab1c-07a9691eef4f.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /home/jmcfaul/pyrkenv/lib64/python3.8/site-packages/IPython/core/interactiveshell.py:3516: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
os.listdir()
# Out:
# ['.git',
#  '.github',
#  '.gitignore',
#  'CHANGELOG',
#  'CITATION.md',
#  'CONTRIBUTING.md',
#  'README.md',
#  'doc',
#  'examples',
#  'licenses',
#  'pyrk',
#  'requirements.txt',
#  'setup.py',
#  'RELEASE-VERSION',
#  'pyrk.egg-info',
#  'build',
#  'dist',
#  '.ipynb_checkpoints',
#  'test.ipynb']
